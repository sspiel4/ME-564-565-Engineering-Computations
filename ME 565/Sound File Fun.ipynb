# %%
import soundfile as sf

import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
FilterHall, samplerate = sf.read('FilterEcho.wav')
sound1, samplerate = sf.read('sound1.wav')

# %%
FilterHall.shape
# Out:
# (44100,)

# %%
sound1.shape
# Out:
# (17112,)

# %%
plt.plot(sound1);

# %%
plt.plot(FilterHall);

# %%
convolve = np.convolve(sound1, FilterHall[1])*10000000

# %%
plt.plot(convolve);

# %%
sf.write('my_pcm16_file.wav', convolve, samplerate)
