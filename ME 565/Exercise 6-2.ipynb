# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
import numpy as np
import math

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.cm as cm

# %%
dx = 0.01
start = -2
stop = 2
x = np.arange(start, stop, dx)

L = stop-start

# %%
f = np.zeros(len(x))
div = math.floor(len(f)/4)

for i in range (0,div):
    f[i] = 0
for i in range (div,2*div):
    f[i] = 1
for i in range (2*div,3*div):
    f[i] = 1
for i in range (3*div,4*div):
    f[i] = 0

# %%
A0 = (2/L)*np.trapz(f,x,dx)
fFS = A0/2

Akn=[]
Bkn=[]
mult = 1

#for m in range (1,40):
#    fFS = A0/2

D=math.floor(len(x)*mult)

for k in range (1,200):
    Ak = (2/(L*(mult)))*np.trapz((f*np.cos(2*np.pi*k*x/L)),x,dx)
    Akn.append(Ak)
    Bk = (2/(L*(mult)))*np.trapz((f*np.sin(2*np.pi*k*x/L)),x,dx)
    Bkn.append(Bk)
    fFS = fFS + Ak*np.cos(2*k*np.pi*x/L) + Bk*np.sin(2*k*np.pi*x/L)
    
D
# Out:
# 400

# %%
d = np.arange(1, D, 1)

# %%
#create figure object
fig = plt.figure()

#plot each set of y values with respect to time
ax = fig.add_axes([0,0,1,1])

ax.plot(d[0:100],Akn[0:100], label = 'Akn')
ax.plot(d[0:100],Bkn[0:100], label = 'Bkn')

#set limits on x axis
ax.set_xlim(0,100)
ax.set_ylim(-1,1)

#title axis
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Excercise 2-5: Taylor Expansion')

#include legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()
plt.close('all')

# %%
#create figure object
fig = plt.figure()

#plot each set of y values with respect to time
ax = fig.add_axes([0,0,1,1])

ax.plot(x,fFS, label = 'fFS')
ax.plot(x,f, '--', label = 'f')

#set limits on x axis
ax.set_xlim(start,stop)
ax.set_ylim(-2,2)

#title axis
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Excercise 2-5: Taylor Expansion')

#include legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()
plt.close('all')

# %%
diff = f[1]=fFS[1]
diff
# Out:
# -3.3391712517868294e-14
