# %%
import numpy as np
from scipy import integrate
from numpy import linalg as LA
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
A = np.array([[-1,2],[2,-1]])
eigs, e_vect = LA.eig(A)
print(eigs)
print(e_vect)
# Out:
# [ 1. -3.]
# [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]

# %%
T = e_vect
T_inv = LA.inv(T)
print('A-Matrix')
print(A)
print('T-Matrix')
print(T)
print('T-1-Matrix')
print(T_inv)
# Out:
# A-Matrix
# [[-1  2]
#  [ 2 -1]]
# T-Matrix
# [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]
# T-1-Matrix
# [[ 0.70710678  0.70710678]
#  [-0.70710678  0.70710678]]

# %%
#Solve ODE
def solvr(Y, t):
    return [-1*Y[0] + 2*Y[1], 2 * Y[0] -1* Y[1]]

#establish a time range to compute the solution
a_t = np.arange(0, 10, 0.01)
#matrix returned from solvr, initial conditions, time range.
asol = integrate.odeint(solvr, [2, 2], a_t)
p = asol[:,1:2]

y_solve = 2 * np.exp(a_t*-3) + 2 * np.exp(a_t)

# %%
#create figure object
fig = plt.figure()

#plot each set of y values with respect to time
ax = fig.add_axes([0,0,1,1])
ax.plot(a_t,p, label='System Behavior')

#set limits on x axis
ax.set_xlim(0,10)

#title axis
ax.set_xlabel('time (t)')
ax.set_ylabel(' (x)')
ax.set_title('Excercise 1-2')

#include legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()

# %%
#create figure object
fig = plt.figure()

#plot each set of y values with respect to time
ax = fig.add_axes([0,0,1,1])
ax.plot(a_t,y_solve, label='System Behavior')

#set limits on x axis
ax.set_xlim(0,10)

#title axis
ax.set_xlabel('time (t)')
ax.set_ylabel(' (x)')
ax.set_title('Excercise 1-2')

#include legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()

# %%
z = p - y_solve
